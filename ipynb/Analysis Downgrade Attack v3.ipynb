# %% [markdown]
# # DNSSEC-Aware Resolver Downgrade Attacks
#
# This notebook contains data collection and analysis code to study resolver populations ("groups") for their vulnerability towards downgrade attacks.
#
# Prerequisite for running this notebook is a properly setup test zone at `downgrade.dedyn.io` (see `ZONE` variable below).

# %%
import logging
import random
import string
from datetime import datetime
import itertools
import concurrent
import math

import numpy as np
import dns.message, dns.query, dns.rdataclass, dns.rdatatype, dns.flags, dns.exception, dns.name, dns.dnssec
from tqdm import tqdm
import pandas as pd
import requests

import random

# <Elias' local stuff>
REPO_DIR = '../../dnssec-downgrade-data/'
DATA_DIR = REPO_DIR + '/2021-10-08_open-resolvers-anon/'  # location of input/raw and processed data
STATS_DIR = DATA_DIR + '/stats/' # output location fo tables and plots
CSV_FILENAME_OPN_ANON = DATA_DIR + "rapid7-resolvers-dev.txt"
CSV_FILENAME_OPN_NAMED = DATA_DIR + "open-resolvers.csv"
CSV_FILENAME_LAB = DATA_DIR + "lab-resolvers.csv"
DF_ALGO_SUPPORT_PICKLE_FILENAME = DATA_DIR + "df_resolver_algo_support.pickle.gz"
# </Elias' local stuff>

NUM_EXECUTOR_THREADS = 15
TOKEN_DIGITS = 8  # number of alphanumeric characters to use as token to identify a resolver at the downgrade NS with 
USE_FIRST_N_IPS = 1000  # may include non-responders, non-resolvers, non-validators; (# CSV rows from Rapid7 portscans); expect ~5% recall from port responders to investigated DNSSEC validators
RESOLUTION_CHECK_DOMAIN = "ns.x.dnsstu.de"  # for liveliness check of (esp. anonymous) resolvers
RESOLUTION_CHECK_ADDRESS = "141.12.174.24"


IN = dns.rdataclass.from_text("IN")
NS = dns.rdatatype.from_text("NS")
SOA = dns.rdatatype.from_text("SOA")
DS = dns.rdatatype.from_text("DS")
A = dns.rdatatype.from_text("A")
TXT = dns.rdatatype.from_text("TXT")
AAAA = dns.rdatatype.from_text("AAAA")
RRSIG = dns.rdatatype.from_text("RRSIG")

ALGORITHMS = [
    # all relevant DNSSEC algorithms
    dns.dnssec.RSASHA1,
    dns.dnssec.RSASHA256,
    dns.dnssec.RSASHA512,
    dns.dnssec.ECDSAP256SHA256,
    dns.dnssec.ECDSAP384SHA384,
    dns.dnssec.ED25519,
    dns.dnssec.ED448,
]

ALGORITHMS_RED = ALGORITHMS = [
    # all DNSSEC algorithms used in this study
    dns.dnssec.RSASHA1,
    dns.dnssec.RSASHA256,
    dns.dnssec.ECDSAP256SHA256,
    dns.dnssec.ED25519,
    dns.dnssec.ED448,
]

ZONE = dns.name.from_text('downgrade.dedyn.io')

executor = concurrent.futures.ThreadPoolExecutor(NUM_EXECUTOR_THREADS)  # increase number of workers to decrease runtime of the study at the risk of overloading the Internet connection and/or auth NS

def query(qname, resolver, cd, rdtype=A):
    """Wrapper method to query resolvers for data. Retries once on timeouts."""
    q = dns.message.make_query(qname, rdtype)
    q.flags |= dns.flags.AD
    if cd:
        q.flags |= dns.flags.CD
    
    if resolver.startswith('https'):
        method = dns.query.https
        where = resolver
    elif resolver.startswith('tls'):
        method = dns.query.tls
        where = resolver[len('tls://'):]
    else:
        method = dns.query.udp
        where = resolver
        
    logging.info(f'Query:\n{q}')
    
    try:
        return method(q, where=where, timeout=2)
    except (dns.exception.Timeout, requests.exceptions.ReadTimeout, EOFError):
        return method(q, where=where, timeout=5)
    
def run(f, args_list):
    """Calls function f for each args in args_list once, using multi-threading."""
    results = []    
    try:
        futures = [executor.submit(f, *args) for args in args_list]
        with tqdm(total=len(futures)) as pbar:
            for future in concurrent.futures.as_completed(futures):
                pbar.update(1)
                if future.exception():
                    logging.warning(f"{future.exception()}")
                    results.append({'status': future.exception()})
                else:
                    results.append(future.result())
    finally:
        return results

# %% [markdown]
# ## Define Test Zones with Different Combinations of DS and DNSKEY Records
#
# Our study runs on zones with various DS and DNSKEY configurations. Which exactly is determined below. Note that these zones must exist and may need to be configured at the auth NS.

# %%
zones = [
    {
        'ds': algos, 
        'dnskey': tuple(sorted(set(algos) - set(remove_dnskeys))),
        'name': dns.name.from_text(
            "-".join(
                [f"ds{a}" for a in sorted(algos)] +
                [f"dnskey{int(a)}" for a in sorted(set(algos) - set(remove_dnskeys))]
            ),
            origin=ZONE
        ),
    }
    for algos in itertools.chain(itertools.combinations(ALGORITHMS, 1), itertools.combinations(ALGORITHMS_RED, 2))
    for remove_dnskeys in [[a for i, a in enumerate(algos) if v[i]] for v in itertools.product([True, False], repeat=len(algos))]
    #if 16 in algos
]
zones = pd.DataFrame(zones)
zones = zones.set_index('name')
zones
# Out:
#                                                                                                   ds  \
# name
# (b'ds5', b'downgrade', b'dedyn', b'io', b'')                                    (Algorithm.RSASHA1,)
# (b'ds5-dnskey5', b'downgrade', b'dedyn', b'io',...                              (Algorithm.RSASHA1,)
# (b'ds8', b'downgrade', b'dedyn', b'io', b'')                                  (Algorithm.RSASHA256,)
# (b'ds8-dnskey8', b'downgrade', b'dedyn', b'io',...                            (Algorithm.RSASHA256,)
# (b'ds13', b'downgrade', b'dedyn', b'io', b'')                           (Algorithm.ECDSAP256SHA256,)
# (b'ds13-dnskey13', b'downgrade', b'dedyn', b'io...                      (Algorithm.ECDSAP256SHA256,)
# (b'ds15', b'downgrade', b'dedyn', b'io', b'')                                   (Algorithm.ED25519,)
# (b'ds15-dnskey15', b'downgrade', b'dedyn', b'io...                              (Algorithm.ED25519,)
# (b'ds16', b'downgrade', b'dedyn', b'io', b'')                                     (Algorithm.ED448,)
# (b'ds16-dnskey16', b'downgrade', b'dedyn', b'io...                                (Algorithm.ED448,)
# (b'ds5-ds8', b'downgrade', b'dedyn', b'io', b'')            (Algorithm.RSASHA1, Algorithm.RSASHA256)
# (b'ds5-ds8-dnskey8', b'downgrade', b'dedyn', b'...          (Algorithm.RSASHA1, Algorithm.RSASHA256)
# (b'ds5-ds8-dnskey5', b'downgrade', b'dedyn', b'...          (Algorithm.RSASHA1, Algorithm.RSASHA256)
# (b'ds5-ds8-dnskey5-dnskey8', b'downgrade', b'de...          (Algorithm.RSASHA1, Algorithm.RSASHA256)
# (b'ds5-ds13', b'downgrade', b'dedyn', b'io', b'')     (Algorithm.RSASHA1, Algorithm.ECDSAP256SHA256)
# (b'ds5-ds13-dnskey13', b'downgrade', b'dedyn', ...    (Algorithm.RSASHA1, Algorithm.ECDSAP256SHA256)
# (b'ds5-ds13-dnskey5', b'downgrade', b'dedyn', b...    (Algorithm.RSASHA1, Algorithm.ECDSAP256SHA256)
# (b'ds5-ds13-dnskey5-dnskey13', b'downgrade', b'...    (Algorithm.RSASHA1, Algorithm.ECDSAP256SHA256)
# (b'ds5-ds15', b'downgrade', b'dedyn', b'io', b'')             (Algorithm.RSASHA1, Algorithm.ED25519)
# (b'ds5-ds15-dnskey15', b'downgrade', b'dedyn', ...            (Algorithm.RSASHA1, Algorithm.ED25519)
# (b'ds5-ds15-dnskey5', b'downgrade', b'dedyn', b...            (Algorithm.RSASHA1, Algorithm.ED25519)
# (b'ds5-ds15-dnskey5-dnskey15', b'downgrade', b'...            (Algorithm.RSASHA1, Algorithm.ED25519)
# (b'ds5-ds16', b'downgrade', b'dedyn', b'io', b'')               (Algorithm.RSASHA1, Algorithm.ED448)
# (b'ds5-ds16-dnskey16', b'downgrade', b'dedyn', ...              (Algorithm.RSASHA1, Algorithm.ED448)
# (b'ds5-ds16-dnskey5', b'downgrade', b'dedyn', b...              (Algorithm.RSASHA1, Algorithm.ED448)
# (b'ds5-ds16-dnskey5-dnskey16', b'downgrade', b'...              (Algorithm.RSASHA1, Algorithm.ED448)
# (b'ds8-ds13', b'downgrade', b'dedyn', b'io', b'')   (Algorithm.RSASHA256, Algorithm.ECDSAP256SHA256)
# (b'ds8-ds13-dnskey13', b'downgrade', b'dedyn', ...  (Algorithm.RSASHA256, Algorithm.ECDSAP256SHA256)
# (b'ds8-ds13-dnskey8', b'downgrade', b'dedyn', b...  (Algorithm.RSASHA256, Algorithm.ECDSAP256SHA256)
# (b'ds8-ds13-dnskey8-dnskey13', b'downgrade', b'...  (Algorithm.RSASHA256, Algorithm.ECDSAP256SHA256)
# (b'ds8-ds15', b'downgrade', b'dedyn', b'io', b'')           (Algorithm.RSASHA256, Algorithm.ED25519)
# (b'ds8-ds15-dnskey15', b'downgrade', b'dedyn', ...          (Algorithm.RSASHA256, Algorithm.ED25519)
# (b'ds8-ds15-dnskey8', b'downgrade', b'dedyn', b...          (Algorithm.RSASHA256, Algorithm.ED25519)
# (b'ds8-ds15-dnskey8-dnskey15', b'downgrade', b'...          (Algorithm.RSASHA256, Algorithm.ED25519)
# (b'ds8-ds16', b'downgrade', b'dedyn', b'io', b'')             (Algorithm.RSASHA256, Algorithm.ED448)
# (b'ds8-ds16-dnskey16', b'downgrade', b'dedyn', ...            (Algorithm.RSASHA256, Algorithm.ED448)
# (b'ds8-ds16-dnskey8', b'downgrade', b'dedyn', b...            (Algorithm.RSASHA256, Algorithm.ED448)
# (b'ds8-ds16-dnskey8-dnskey16', b'downgrade', b'...            (Algorithm.RSASHA256, Algorithm.ED448)
# (b'ds13-ds15', b'downgrade', b'dedyn', b'io', b'')    (Algorithm.ECDSAP256SHA256, Algorithm.ED25519)
# (b'ds13-ds15-dnskey15', b'downgrade', b'dedyn',...    (Algorithm.ECDSAP256SHA256, Algorithm.ED25519)
# (b'ds13-ds15-dnskey13', b'downgrade', b'dedyn',...    (Algorithm.ECDSAP256SHA256, Algorithm.ED25519)
# (b'ds13-ds15-dnskey13-dnskey15', b'downgrade', ...    (Algorithm.ECDSAP256SHA256, Algorithm.ED25519)
# (b'ds13-ds16', b'downgrade', b'dedyn', b'io', b'')      (Algorithm.ECDSAP256SHA256, Algorithm.ED448)
# (b'ds13-ds16-dnskey16', b'downgrade', b'dedyn',...      (Algorithm.ECDSAP256SHA256, Algorithm.ED448)
# (b'ds13-ds16-dnskey13', b'downgrade', b'dedyn',...      (Algorithm.ECDSAP256SHA256, Algorithm.ED448)
# (b'ds13-ds16-dnskey13-dnskey16', b'downgrade', ...      (Algorithm.ECDSAP256SHA256, Algorithm.ED448)
# (b'ds15-ds16', b'downgrade', b'dedyn', b'io', b'')              (Algorithm.ED25519, Algorithm.ED448)
# (b'ds15-ds16-dnskey16', b'downgrade', b'dedyn',...              (Algorithm.ED25519, Algorithm.ED448)
# (b'ds15-ds16-dnskey15', b'downgrade', b'dedyn',...              (Algorithm.ED25519, Algorithm.ED448)
# (b'ds15-ds16-dnskey15-dnskey16', b'downgrade', ...              (Algorithm.ED25519, Algorithm.ED448)
#
#                                                                                               dnskey
# name
# (b'ds5', b'downgrade', b'dedyn', b'io', b'')                                                      ()
# (b'ds5-dnskey5', b'downgrade', b'dedyn', b'io',...                              (Algorithm.RSASHA1,)
# (b'ds8', b'downgrade', b'dedyn', b'io', b'')                                                      ()
# (b'ds8-dnskey8', b'downgrade', b'dedyn', b'io',...                            (Algorithm.RSASHA256,)
# (b'ds13', b'downgrade', b'dedyn', b'io', b'')                                                     ()
# (b'ds13-dnskey13', b'downgrade', b'dedyn', b'io...                      (Algorithm.ECDSAP256SHA256,)
# (b'ds15', b'downgrade', b'dedyn', b'io', b'')                                                     ()
# (b'ds15-dnskey15', b'downgrade', b'dedyn', b'io...                              (Algorithm.ED25519,)
# (b'ds16', b'downgrade', b'dedyn', b'io', b'')                                                     ()
# (b'ds16-dnskey16', b'downgrade', b'dedyn', b'io...                                (Algorithm.ED448,)
# (b'ds5-ds8', b'downgrade', b'dedyn', b'io', b'')                                                  ()
# (b'ds5-ds8-dnskey8', b'downgrade', b'dedyn', b'...                            (Algorithm.RSASHA256,)
# (b'ds5-ds8-dnskey5', b'downgrade', b'dedyn', b'...                              (Algorithm.RSASHA1,)
# (b'ds5-ds8-dnskey5-dnskey8', b'downgrade', b'de...          (Algorithm.RSASHA1, Algorithm.RSASHA256)
# (b'ds5-ds13', b'downgrade', b'dedyn', b'io', b'')                                                 ()
# (b'ds5-ds13-dnskey13', b'downgrade', b'dedyn', ...                      (Algorithm.ECDSAP256SHA256,)
# (b'ds5-ds13-dnskey5', b'downgrade', b'dedyn', b...                              (Algorithm.RSASHA1,)
# (b'ds5-ds13-dnskey5-dnskey13', b'downgrade', b'...    (Algorithm.RSASHA1, Algorithm.ECDSAP256SHA256)
# (b'ds5-ds15', b'downgrade', b'dedyn', b'io', b'')                                                 ()
# (b'ds5-ds15-dnskey15', b'downgrade', b'dedyn', ...                              (Algorithm.ED25519,)
# (b'ds5-ds15-dnskey5', b'downgrade', b'dedyn', b...                              (Algorithm.RSASHA1,)
# (b'ds5-ds15-dnskey5-dnskey15', b'downgrade', b'...            (Algorithm.RSASHA1, Algorithm.ED25519)
# (b'ds5-ds16', b'downgrade', b'dedyn', b'io', b'')                                                 ()
# (b'ds5-ds16-dnskey16', b'downgrade', b'dedyn', ...                                (Algorithm.ED448,)
# (b'ds5-ds16-dnskey5', b'downgrade', b'dedyn', b...                              (Algorithm.RSASHA1,)
# (b'ds5-ds16-dnskey5-dnskey16', b'downgrade', b'...              (Algorithm.RSASHA1, Algorithm.ED448)
# (b'ds8-ds13', b'downgrade', b'dedyn', b'io', b'')                                                 ()
# (b'ds8-ds13-dnskey13', b'downgrade', b'dedyn', ...                      (Algorithm.ECDSAP256SHA256,)
# (b'ds8-ds13-dnskey8', b'downgrade', b'dedyn', b...                            (Algorithm.RSASHA256,)
# (b'ds8-ds13-dnskey8-dnskey13', b'downgrade', b'...  (Algorithm.RSASHA256, Algorithm.ECDSAP256SHA256)
# (b'ds8-ds15', b'downgrade', b'dedyn', b'io', b'')                                                 ()
# (b'ds8-ds15-dnskey15', b'downgrade', b'dedyn', ...                              (Algorithm.ED25519,)
# (b'ds8-ds15-dnskey8', b'downgrade', b'dedyn', b...                            (Algorithm.RSASHA256,)
# (b'ds8-ds15-dnskey8-dnskey15', b'downgrade', b'...          (Algorithm.RSASHA256, Algorithm.ED25519)
# (b'ds8-ds16', b'downgrade', b'dedyn', b'io', b'')                                                 ()
# (b'ds8-ds16-dnskey16', b'downgrade', b'dedyn', ...                                (Algorithm.ED448,)
# (b'ds8-ds16-dnskey8', b'downgrade', b'dedyn', b...                            (Algorithm.RSASHA256,)
# (b'ds8-ds16-dnskey8-dnskey16', b'downgrade', b'...            (Algorithm.RSASHA256, Algorithm.ED448)
# (b'ds13-ds15', b'downgrade', b'dedyn', b'io', b'')                                                ()
# (b'ds13-ds15-dnskey15', b'downgrade', b'dedyn',...                              (Algorithm.ED25519,)
# (b'ds13-ds15-dnskey13', b'downgrade', b'dedyn',...                      (Algorithm.ECDSAP256SHA256,)
# (b'ds13-ds15-dnskey13-dnskey15', b'downgrade', ...    (Algorithm.ECDSAP256SHA256, Algorithm.ED25519)
# (b'ds13-ds16', b'downgrade', b'dedyn', b'io', b'')                                                ()
# (b'ds13-ds16-dnskey16', b'downgrade', b'dedyn',...                                (Algorithm.ED448,)
# (b'ds13-ds16-dnskey13', b'downgrade', b'dedyn',...                      (Algorithm.ECDSAP256SHA256,)
# (b'ds13-ds16-dnskey13-dnskey16', b'downgrade', ...      (Algorithm.ECDSAP256SHA256, Algorithm.ED448)
# (b'ds15-ds16', b'downgrade', b'dedyn', b'io', b'')                                                ()
# (b'ds15-ds16-dnskey16', b'downgrade', b'dedyn',...                                (Algorithm.ED448,)
# (b'ds15-ds16-dnskey15', b'downgrade', b'dedyn',...                              (Algorithm.ED25519,)
# (b'ds15-ds16-dnskey15-dnskey16', b'downgrade', ...              (Algorithm.ED25519, Algorithm.ED448)

# %% [markdown]
# ## Define Resolver Populations to be Studied
#
# Creates a list of resolvers to be studied and determines their algorithm support.

# %%
open_resolvers = [{'resolver_addr': row['IPv4'], 'resolver_name': row['Handle'], 'resolver_group': 'open-named'} for _, row in pd.read_csv(CSV_FILENAME_OPN_NAMED).iterrows()]
lab_resolvers = [{'resolver_addr': row['IPv4'], 'resolver_name': row['Handle'], 'resolver_group': 'lab'} for _, row in pd.read_csv(CSV_FILENAME_LAB).iterrows()]
anon_resolvers = [{'resolver_addr': row['IPv4'], 'resolver_name': f"{row['IPv4'].replace('.', '-')}", 'resolver_group': 'open-anon'} for _, row in pd.read_csv(CSV_FILENAME_OPN_ANON, nrows=USE_FIRST_N_IPS).iterrows()]

# %%
def convert_resolver_format(d):
    return [{'resolver_addr': addr, 'resolver_name': handle, 'resolver_group': 'open-named'} for handle, addr in d.items()]
    
doh_resolvers = convert_resolver_format({
    'cloudflare-doh': 'https://cloudflare-dns.com/dns-query',
    'cloudflare-mozilla-doh': 'https://mozilla.cloudflare-dns.com/dns-query',
    'google-doh': 'https://dns.google/dns-query',
    'quad9-doh': 'https://dns.quad9.net/dns-query',
    # 'clean-browsing-doh': 'https://security-filter-dns.cleanbrowsing.org/dns-query',
    'adguard-doh': 'https://dns.adguard.com/dns-query',
    'comcast-doh': 'https://doh.xfinity.com/dns-query',
})
dot_resolvers = convert_resolver_format({
    'cloudflare-dot': 'tls://1.1.1.1',
    'google-dot': 'tls://8.8.8.8',
    'quad9-dot': 'tls://9.9.9.9',
    'clean-browsing-dot': 'tls://185.228.168.9',
    'adguard-dot': 'tls://94.140.14.14',
})

# %%
def resolver_transport(row):
    if row['resolver_addr'].startswith('tls'):
        return 'DoT'
    if row['resolver_addr'].startswith('https'):
        return 'DoH'
    return 'UDP/TCP'


resolver_list = pd.DataFrame(
    open_resolvers + lab_resolvers + 
    doh_resolvers + dot_resolvers + anon_resolvers
)
resolver_list['resolver_transport'] = resolver_list.apply(resolver_transport, axis=1)
resolver_list[resolver_list['resolver_group'] == 'open-anon'].head(15)
# Out:
#       resolver_addr    resolver_name resolver_group resolver_transport
# 31  122.168.126.179  122-168-126-179      open-anon            UDP/TCP
# 32   51.178.122.252   51-178-122-252      open-anon            UDP/TCP
# 33    112.254.9.185    112-254-9-185      open-anon            UDP/TCP
# 34     72.222.94.48     72-222-94-48      open-anon            UDP/TCP
# 35    96.30.125.130    96-30-125-130      open-anon            UDP/TCP
# 36   209.112.234.83   209-112-234-83      open-anon            UDP/TCP
# 37  218.108.186.108  218-108-186-108      open-anon            UDP/TCP
# 38     210.36.57.48     210-36-57-48      open-anon            UDP/TCP
# 39  170.246.172.216  170-246-172-216      open-anon            UDP/TCP
# 40    103.130.60.52    103-130-60-52      open-anon            UDP/TCP
# 41     111.61.77.72     111-61-77-72      open-anon            UDP/TCP
# 42     23.185.192.2     23-185-192-2      open-anon            UDP/TCP
# 43    202.70.65.153    202-70-65-153      open-anon            UDP/TCP
# 44    95.43.242.225    95-43-242-225      open-anon            UDP/TCP
# 45   103.127.144.42   103-127-144-42      open-anon            UDP/TCP

# %%
resolver_list['token'] = resolver_list.apply(lambda x: ''.join(random.choices(string.ascii_lowercase + string.digits, k=TOKEN_DIGITS)), axis=1)
resolver_list.head(5)
# Out:
#     resolver_addr      resolver_name resolver_group resolver_transport  \
# 0  208.67.222.222     cisco-umbrella     open-named            UDP/TCP
# 1         1.1.1.1         cloudflare     open-named            UDP/TCP
# 2      8.26.56.26  comodo-secure-dns     open-named            UDP/TCP
# 3     193.17.47.1         cznic-odvr     open-named            UDP/TCP
# 4     80.80.80.80      freenom-world     open-named            UDP/TCP
#
#       token
# 0  r62gzho0
# 1  9l9f0qse
# 2  t20i83fk
# 3  7j9mavre
# 4  fcxcxuuw

# %% [markdown]
# ### Determine Resolver Liveliness

# %% [markdown]
# - check alive on all resolvers by resolving a test domain (i.e. whether the DNS server correctly resolves a name under our control)
# - assert only opn-anon resolvers are under the dead resolvers

# %%
def check_resolver_alive(resolver):
    # check whether the resolver is an actual resolver (yields A-record of our test domain)
    def check_response(response_msg):
        """Returns True iff the response contains a NOERROR answer carrying the target A record, i.e. if the resolver is alive."""
        if response_msg.rcode() != dns.rcode.NOERROR:
            return False
        for rrset in response_msg.answer:
            for rdat in rrset:
                if rdat.to_text() == RESOLUTION_CHECK_ADDRESS:
                    return True
        return False

    try:
        qname = dns.name.from_text(RESOLUTION_CHECK_DOMAIN)
        r = query(qname, resolver['resolver_addr'], cd=False, rdtype=A)  # must return 141.12.174.24 (RESOLUTION_CHECK_ADDRESS)
        return {
            **resolver,
            'alive': check_response(r),
            'status': 'ok'
        }
    except (dns.exception.Timeout, requests.exceptions.ReadTimeout, EOFError):
        return {
            **resolver,
            'alive': False,
            'status': 'timeout',
        }
    except Exception as e:
        return {
            **resolver,
            'alive': False,
            'status': (type(e), e),
        }

# %%
logging.basicConfig(level=logging.WARNING, force=True)

# %%
resolver_liveliness_results = run(check_resolver_alive, [(resolver,) for _, resolver in resolver_list.iterrows()])
resolver_liveliness_pd = pd.DataFrame(resolver_liveliness_results)
resolver_liveliness_pd
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1031/1031 [00:40<00:00, 25.49it/s]
#         resolver_addr       resolver_name resolver_group resolver_transport  \
# 0             1.1.1.1          cloudflare     open-named            UDP/TCP
# 1       199.85.126.10  norton-connectsafe     open-named            UDP/TCP
# 2       141.12.174.44              ws2012            lab            UDP/TCP
# 3             8.8.8.8              google     open-named            UDP/TCP
# 4       216.146.35.35          oracle-dyn     open-named            UDP/TCP
# ...               ...                 ...            ...                ...
# 1026   122.227.89.102      122-227-89-102      open-anon            UDP/TCP
# 1027  159.192.120.127     159-192-120-127      open-anon            UDP/TCP
# 1028    45.190.34.161       45-190-34-161      open-anon            UDP/TCP
# 1029     61.219.97.73        61-219-97-73      open-anon            UDP/TCP
# 1030    103.30.247.49       103-30-247-49      open-anon            UDP/TCP
#
#          token  alive   status
# 0     9l9f0qse   True       ok
# 1     5fv4de9a   True       ok
# 2     sose6huv   True       ok
# 3     jn82fsjr   True       ok
# 4     v7ccn8u1   True       ok
# ...        ...    ...      ...
# 1026  wtj1er19   True       ok
# 1027  4p86iqte   True       ok
# 1028  tyfzcykl  False  timeout
# 1029  t08knyjm   True       ok
# 1030  lwrt03ru  False  timeout
#
# [1031 rows x 7 columns]

# %%
resolver_liveliness_counts = resolver_liveliness_pd[['resolver_addr', 'resolver_group', 'alive']].groupby(['resolver_group', 'alive']).count()
resolver_liveliness_counts
# Out:
#                       resolver_addr
# resolver_group alive
# lab            True               8
# open-anon      False             13
#                True             987
# open-named     True              23

# %% [raw]
# # Show Non-Alive Cases from Lab or Open Named Resolvers
# BAD_LABEL_ERR_MSG = """(<class 'dns.name.BadLabelType'>, The label type in DNS name wire format is unknown.)"""
# resolver_liveliness_pd[(~resolver_liveliness_pd['alive']) & (resolver_liveliness_pd['resolver_group'] != 'open-anon')]

# %%
# make sure we can reach all lab resolvers and named open resolvers in the scan
assert resolver_liveliness_counts.loc['lab', True]['resolver_addr'] == 8  # we want all 8 lab resolvers to be responsive
assert resolver_liveliness_counts.loc['open-named', True]['resolver_addr'] == 23
# resolver_liveliness_counts

# %% [markdown]
# #### Keep only Resolvers that are alive
# *to reduce timeouts*

# %%
# resolver_list = resolver_liveliness_pd[resolver_liveliness_pd['alive']][['resolver_addr', 'resolver_name', 'resolver_group', 'resolver_transport', 'token']]
resolver_list = resolver_list[resolver_list['resolver_addr'].isin(resolver_liveliness_pd[resolver_liveliness_pd['alive']]['resolver_addr'])]
resolver_list.head(25)
# Out:
#                                    resolver_addr           resolver_name  \
# 0                                 208.67.222.222          cisco-umbrella
# 1                                        1.1.1.1              cloudflare
# 2                                     8.26.56.26       comodo-secure-dns
# 3                                    193.17.47.1              cznic-odvr
# 4                                    80.80.80.80           freenom-world
# 5                                        8.8.8.8                  google
# 6                                   156.154.70.1  neustar-free-recursive
# 7                                  199.85.126.10      norton-connectsafe
# 8                                  194.36.144.87                 opennic
# 9                                  216.146.35.35              oracle-dyn
# 10                                       9.9.9.9                   quad9
# 11                                     64.6.64.6                verisign
# 12                                 141.12.174.44                  ws2012
# 13                                 141.12.174.11                ws2012r2
# 14                                 141.12.174.42                  ws2016
# 15                                 141.12.174.63                  ws2019
# 16                                 141.12.174.29                bind9113
# 17                                 141.12.174.30                kresd532
# 18                                 141.12.174.38             powerdns460
# 19                                 141.12.174.39              unbound167
# 20          https://cloudflare-dns.com/dns-query          cloudflare-doh
# 21  https://mozilla.cloudflare-dns.com/dns-query  cloudflare-mozilla-doh
# 22                  https://dns.google/dns-query              google-doh
# 23               https://dns.quad9.net/dns-query               quad9-doh
# 24             https://dns.adguard.com/dns-query             adguard-doh
#
#    resolver_group resolver_transport     token
# 0      open-named            UDP/TCP  r62gzho0
# 1      open-named            UDP/TCP  9l9f0qse
# 2      open-named            UDP/TCP  t20i83fk
# 3      open-named            UDP/TCP  7j9mavre
# 4      open-named            UDP/TCP  fcxcxuuw
# 5      open-named            UDP/TCP  jn82fsjr
# 6      open-named            UDP/TCP  xjlza3o9
# 7      open-named            UDP/TCP  5fv4de9a
# 8      open-named            UDP/TCP  y7peldat
# 9      open-named            UDP/TCP  v7ccn8u1
# 10     open-named            UDP/TCP  hxdgldks
# 11     open-named            UDP/TCP  47jqykw6
# 12            lab            UDP/TCP  sose6huv
# 13            lab            UDP/TCP  reaqnjm6
# 14            lab            UDP/TCP  exe67hx4
# 15            lab            UDP/TCP  xh4lygsm
# 16            lab            UDP/TCP  qmrz8uyn
# 17            lab            UDP/TCP  jm54p5wj
# 18            lab            UDP/TCP  5mbf8gkr
# 19            lab            UDP/TCP  q021wfr1
# 20     open-named                DoH  0mf1o1j5
# 21     open-named                DoH  dkccramf
# 22     open-named                DoH  f20xay8z
# 23     open-named                DoH  wqpe66n3
# 24     open-named                DoH  e44n6kwg

# %% [markdown]
# ### Determine Resolver Cipher Support

# %%
def check_resolver(resolver, algorithm):
    try:
        qname = dns.name.from_text(f'mitm-tok{resolver["token"]}-ms.ds{algorithm}-dnskey{algorithm}', origin=ZONE)
        # qname = dns.name.from_text(f'mitm-ms.ds{algorithm}-dnskey{algorithm}', origin=ZONE)
        
        r = query(qname, resolver['resolver_addr'], cd=False, rdtype=TXT)  # signature invalid
        
        return {
            **resolver,
            'algorithm': algorithm,
            'status': 'ok',
            'qname': qname.to_text(),
            'ad': dns.flags.AD in r.flags,
            'rcode': r.rcode()
        }
    except (dns.exception.Timeout, requests.exceptions.ReadTimeout, EOFError):
        return {
            **resolver,
            'algorithm': algorithm,
            'status': 'timeout',
        }
    except Exception as e:
        return {
            **resolver,
            'algorithm': algorithm,
            'status': (type(e), e),
        }

# %%
resolver_support_results = run(check_resolver, [(resolver, a) for _, resolver in resolver_list.iterrows() for a in ALGORITHMS])
resolver_support = pd.DataFrame(resolver_support_results)
resolver_support.head(15)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5090/5090 [08:11<00:00, 10.35it/s]
#      resolver_addr   resolver_name resolver_group resolver_transport  \
# 0   208.67.222.222  cisco-umbrella     open-named            UDP/TCP
# 1   208.67.222.222  cisco-umbrella     open-named            UDP/TCP
# 2   208.67.222.222  cisco-umbrella     open-named            UDP/TCP
# 3   208.67.222.222  cisco-umbrella     open-named            UDP/TCP
# 4          1.1.1.1      cloudflare     open-named            UDP/TCP
# 5   208.67.222.222  cisco-umbrella     open-named            UDP/TCP
# 6          1.1.1.1      cloudflare     open-named            UDP/TCP
# 7          1.1.1.1      cloudflare     open-named            UDP/TCP
# 8          1.1.1.1      cloudflare     open-named            UDP/TCP
# 9          1.1.1.1      cloudflare     open-named            UDP/TCP
# 10     193.17.47.1      cznic-odvr     open-named            UDP/TCP
# 11     193.17.47.1      cznic-odvr     open-named            UDP/TCP
# 12     193.17.47.1      cznic-odvr     open-named            UDP/TCP
# 13     193.17.47.1      cznic-odvr     open-named            UDP/TCP
# 14     193.17.47.1      cznic-odvr     open-named            UDP/TCP
#
#        token  algorithm status  \
# 0   r62gzho0          8     ok
# 1   r62gzho0          5     ok
# 2   r62gzho0         15     ok
# 3   r62gzho0         13     ok
# 4   9l9f0qse          5     ok
# 5   r62gzho0         16     ok
# 6   9l9f0qse          8     ok
# 7   9l9f0qse         15     ok
# 8   9l9f0qse         13     ok
# 9   9l9f0qse         16     ok
# 10  7j9mavre          5     ok
# 11  7j9mavre          8     ok
# 12  7j9mavre         13     ok
# 13  7j9mavre         15     ok
# 14  7j9mavre         16     ok
#
#                                                 qname     ad  rcode
# 0   mitm-tokr62gzho0-ms.ds8-dnskey8.downgrade.dedy...  False    2.0
# 1   mitm-tokr62gzho0-ms.ds5-dnskey5.downgrade.dedy...  False    2.0
# 2   mitm-tokr62gzho0-ms.ds15-dnskey15.downgrade.de...  False    2.0
# 3   mitm-tokr62gzho0-ms.ds13-dnskey13.downgrade.de...  False    2.0
# 4   mitm-tok9l9f0qse-ms.ds5-dnskey5.downgrade.dedy...  False    2.0
# 5   mitm-tokr62gzho0-ms.ds16-dnskey16.downgrade.de...  False    2.0
# 6   mitm-tok9l9f0qse-ms.ds8-dnskey8.downgrade.dedy...  False    2.0
# 7   mitm-tok9l9f0qse-ms.ds15-dnskey15.downgrade.de...  False    2.0
# 8   mitm-tok9l9f0qse-ms.ds13-dnskey13.downgrade.de...  False    2.0
# 9   mitm-tok9l9f0qse-ms.ds16-dnskey16.downgrade.de...  False    0.0
# 10  mitm-tok7j9mavre-ms.ds5-dnskey5.downgrade.dedy...  False    2.0
# 11  mitm-tok7j9mavre-ms.ds8-dnskey8.downgrade.dedy...  False    2.0
# 12  mitm-tok7j9mavre-ms.ds13-dnskey13.downgrade.de...  False    2.0
# 13  mitm-tok7j9mavre-ms.ds15-dnskey15.downgrade.de...  False    2.0
# 14  mitm-tok7j9mavre-ms.ds16-dnskey16.downgrade.de...  False    0.0

# %%
def support(row):
    def log():
        logging.warning(f'Weird resolver behavior for {row["resolver_name"]}: {row["qname1"]} -> {row["rcode1"]}, {row["qname2"]} -> {row["rcode2"]}')
        
    if row['status'] != 'ok':
        return None
    
    return row['rcode'] == dns.rcode.Rcode.SERVFAIL
    
resolver_support['supported'] = resolver_support.apply(support, axis=1)

# %%
def uncertain_any(s):
    if None in list(s):  # None in s is always false, likely due to pandas' messing with the 'in' operator
        return None
    else:
        return any(s)
    
grouped = resolver_support.groupby(['resolver_addr', 'algorithm'], dropna=False)[['supported']].agg({
    'supported': [uncertain_any]
}).reset_index().pivot(index='resolver_addr', columns='algorithm', values=('supported', 'uncertain_any')).reset_index()
grouped.columns = ['resolver_addr'] + [f'supports_{a}' for a in ALGORITHMS]
resolvers = grouped.set_index('resolver_addr').join(resolver_list.set_index('resolver_addr'))

# %%
resolvers.loc['9.9.9.9', 'supports_16'] = False
resolvers.loc['tls://9.9.9.9', 'supports_16'] = False
resolvers.loc['https://dns.quad9.net/dns-query', 'supports_16'] = False

resolvers['support'] = resolvers.apply(lambda row: tuple(a for a in ALGORITHMS if row[f'supports_{a}'] is True), axis=1)
resolvers
# Out:
#                     supports_5 supports_8 supports_13 supports_15 supports_16  \
# resolver_addr
# 1.1.1.1                   True       True        True        True       False
# 1.199.40.15              False      False       False       False       False
# 101.235.234.30           False      False       False       False       False
# 101.255.49.70             None       None        None        None        None
# 101.255.64.66             True       True        True        True       False
# ...                        ...        ...         ...         ...         ...
# tls://1.1.1.1             True       True        True        True       False
# tls://185.228.168.9       True       True        True        True        True
# tls://8.8.8.8             True       True        True        True       False
# tls://9.9.9.9             True       True        True        True       False
# tls://94.140.14.14        True       True        True        True       False
#
#                           resolver_name resolver_group resolver_transport  \
# resolver_addr
# 1.1.1.1                      cloudflare     open-named            UDP/TCP
# 1.199.40.15                 1-199-40-15      open-anon            UDP/TCP
# 101.235.234.30           101-235-234-30      open-anon            UDP/TCP
# 101.255.49.70             101-255-49-70      open-anon            UDP/TCP
# 101.255.64.66             101-255-64-66      open-anon            UDP/TCP
# ...                                 ...            ...                ...
# tls://1.1.1.1            cloudflare-dot     open-named                DoT
# tls://185.228.168.9  clean-browsing-dot     open-named                DoT
# tls://8.8.8.8                google-dot     open-named                DoT
# tls://9.9.9.9                 quad9-dot     open-named                DoT
# tls://94.140.14.14          adguard-dot     open-named                DoT
#
#                         token  \
# resolver_addr
# 1.1.1.1              9l9f0qse
# 1.199.40.15          15y0jkq3
# 101.235.234.30       8tely464
# 101.255.49.70        frahubzt
# 101.255.64.66        qow1f6qu
# ...                       ...
# tls://1.1.1.1        sqwk1x0s
# tls://185.228.168.9  uww80kx5
# tls://8.8.8.8        j3q3o51o
# tls://9.9.9.9        os7i8db1
# tls://94.140.14.14   uvaiz1o7
#
#                                                                support
# resolver_addr
# 1.1.1.1              (Algorithm.RSASHA1, Algorithm.RSASHA256, Algor...
# 1.199.40.15                                                         ()
# 101.235.234.30                                                      ()
# 101.255.49.70                                                       ()
# 101.255.64.66        (Algorithm.RSASHA1, Algorithm.RSASHA256, Algor...
# ...                                                                ...
# tls://1.1.1.1        (Algorithm.RSASHA1, Algorithm.RSASHA256, Algor...
# tls://185.228.168.9  (Algorithm.RSASHA1, Algorithm.RSASHA256, Algor...
# tls://8.8.8.8        (Algorithm.RSASHA1, Algorithm.RSASHA256, Algor...
# tls://9.9.9.9        (Algorithm.RSASHA1, Algorithm.RSASHA256, Algor...
# tls://94.140.14.14   (Algorithm.RSASHA1, Algorithm.RSASHA256, Algor...
#
# [1018 rows x 10 columns]

# %%
def row_style(row):
    styles = {
        True: 'color: green;',
        False: 'color: red;',
    }
    return [styles.get(v) for v in row]
    
order = ['resolver_group', 'resolver_name', 'resolver_transport']
resolvers.reset_index().set_index(order).sort_values(order).style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# #T_24473_row0_col1, #T_24473_row0_col2, #T_24473_row0_col3, #T_24473_row1_col1, #T_24473_row1_col2, #T_24473_row1_col3, #T_24473_row2_col1, #T_24473_row2_col2, #T_24473_row2_col3, #T_24473_row2_col4, #T_24473_row2_col5, #T_24473_row3_col1, #T_24473_row3_col2, #T_24473_row3_col3, #T_24473_row3_col4, #T_24473_row4_col1, #T_24473_row4_col2, #T_24473_row4_col3, #T_24473_row4_col4, #T_24473_row4_col5, #T_24473_row5_col1, #T_24473_row5_col2, #T_24473_row5_col3, #T_24473_row6_col1, #T_24473_row6_col2, #T_24473_row6_col3, #T_24473_row6_col4, #T_24473_row6_col5, #T_24473_row7_col1, #T_24473_row7_col2, #T_24473_row7_col3, #T_24473_row11_col1, #T_24473_row11_col2, #T_24473_row11_col3, #T_24473_row11_col4, #T_24473_row13_col1, #T_24473_row13_col2, #T_24473_row13_col3, #T_24473_row14_col1, #T_24473_row14_col2, #T_24473_row14_col3, #T_24473_row14_col4, #T_24473_row15_col1, #T_24473_row15_col2, #T_24473_row15_col3, #T_24473_row15_col4, #T_24473_row16_col1, #T_24473_row16_col2, #T_24473_row16_col3, #T_24473_row16_col4, #T_24473_row17_col1, #T_24473_row17_col2, #T_24473_row17_col3, #T_24473_row17_col4, #T_24473_row18_col1, #T_24473_row18_col2, #T_24473_row18_col3, #T_24473_row18_col4, #T_24473_row19_col1, #T_24473_row19_col2, #T_24473_row19_col3, #T_24473_row19_col4, #T_24473_row21_col1, #T_24473_row21_col2, #T_24473_row21_col3, #T_24473_row21_col4, #T_24473_row23_col1, #T_24473_row23_col2, #T_24473_row23_col3, #T_24473_row23_col4, #T_24473_row27_col1, #T_24473_row27_col2, #T_24473_row27_col3, #T_24473_row27_col4, #T_24473_row28_col1, #T_24473_row28_col2, #T_24473_row28_col3, #T_24473_row29_col1, #T_24473_row29_col2, #T_24473_row29_col3, #T_24473_row29_col4, #T_24473_row29_col5, #T_24473_row30_col1, #T_24473_row30_col2, #T_24473_row30_col3, #T_24473_row30_col4, #T_24473_row35_col1, #T_24473_row35_col2, #T_24473_row35_col3, #T_24473_row35_col4, #T_24473_row36_col1, #T_24473_row36_col2, #T_24473_row36_col3, #T_24473_row36_col4, #T_24473_row37_col1, #T_24473_row37_col2, #T_24473_row37_col3, #T_24473_row37_col4, #T_24473_row39_col1, #T_24473_row39_col4, #T_24473_row40_col1, #T_24473_row40_col2, #T_24473_row40_col3, #T_24473_row40_col4, #T_24473_row41_col1, #T_24473_row41_col2, #T_24473_row41_col3, #T_24473_row41_col4, #T_24473_row42_col4, #T_24473_row44_col1, #T_24473_row44_col2, #T_24473_row44_col3, #T_24473_row45_col1, #T_24473_row45_col2, #T_24473_row45_col3, #T_24473_row45_col4, #T_24473_row49_col1, #T_24473_row54_col1, #T_24473_row54_col2, #T_24473_row54_col3, #T_24473_row56_col1, #T_24473_row56_col2, #T_24473_row56_col3, #T_24473_row56_col4, #T_24473_row60_col1, #T_24473_row60_col2, #T_24473_row60_col3, #T_24473_row60_col4, #T_24473_row61_col1, #T_24473_row61_col2, #T_24473_row61_col3, #T_24473_row61_col4, #T_24473_row64_col1, #T_24473_row64_col2, #T_24473_row64_col3, #T_24473_row64_col4, #T_24473_row65_col1, #T_24473_row65_col2, #T_24473_row65_col3, #T_24473_row68_col1, #T_24473_row68_col2, #T_24473_row68_col3, #T_24473_row68_col4, #T_24473_row70_col1, #T_24473_row70_col2, #T_24473_row70_col3, #T_24473_row70_col4, #T_24473_row77_col1, #T_24473_row77_col2, #T_24473_row77_col3, #T_24473_row77_col4, #T_24473_row80_col1, #T_24473_row80_col2, #T_24473_row80_col3, #T_24473_row82_col1, #T_24473_row82_col2, #T_24473_row82_col3, #T_24473_row82_col4, #T_24473_row82_col5, #T_24473_row91_col1, #T_24473_row101_col1, #T_24473_row101_col2, #T_24473_row101_col3, #T_24473_row101_col4, #T_24473_row130_col1, #T_24473_row130_col2, #T_24473_row130_col3, #T_24473_row130_col4, #T_24473_row131_col2, #T_24473_row131_col3, #T_24473_row134_col1, #T_24473_row134_col2, #T_24473_row134_col3, #T_24473_row136_col1, #T_24473_row136_col2, #T_24473_row136_col3, #T_24473_row136_col4, #T_24473_row145_col1, #T_24473_row145_col2, #T_24473_row145_col3, #T_24473_row145_col4, #T_24473_row148_col1, #T_24473_row148_col2, #T_24473_row148_col3, #T_24473_row148_col4, #T_24473_row149_col1, #T_24473_row149_col2, #T_24473_row149_col3, #T_24473_row149_col4, #T_24473_row152_col1, #T_24473_ro ...

# %% [markdown]
# #### Keep only Resolvers that Validate at least one Algorithm

# %%
resolvers['validating'] = resolvers.apply(lambda row: bool(row['support']), axis=1)
resolvers = resolvers[resolvers['validating']]
resolvers[resolvers['resolver_group'] == 'open-anon'].shape
# Out:
# (318, 11)

# %%
resolvers.to_pickle(DF_ALGO_SUPPORT_PICKLE_FILENAME, compression="infer")

# %% [markdown]
# ### Generate Algorithm Support Table

# %%
RESOLVER_NAMES = {
    'bind9113': 'Bind v9.11.3',
    'kresd532': 'Knot Resolver 5.3.2',
    'powerdns460': 'Power DNS Recursor 4.6.0',
    'unbound167': 'Unbound 1.6.7',
    'ws2012': 'Windows Server 2012',
    'ws2012r2': 'Windows Server 2012 R2',
    'ws2016': 'Windows Server 2016',
    'ws2019': 'Windows Server 2019',
    'adguard': 'AdGuard Public DNS',
    'cloudflare': 'Cloudflare Resolver',
    'cloudflare-mozilla': 'Cloudflare Resolver for Mozilla',
    'comcast': 'Comcast Public DNS',
    'google': 'Google Public DNS',
    'quad9': 'Quad9 Resolver',
    'cisco-umbrella': 'Cisco Umbrella',
    'comodo-secure-dns': 'Comodo Secure DNS',
    'cznic-odvr': 'cznic ODVR',
    'freenom-world': 'Freenom World',
    'oracle-dyn': 'Oracle Dyn',
    'yandex': 'Yandex safe'
}

RESOLVER_GROUPS = {
    'lab': 'Lab',
    'open-named': 'Public DNS',
}
ALGORITHM_NAMES = [f"{dns.dnssec.Algorithm.to_text(a)} ({str(int(a))})" for a in ALGORITHMS]
ALGORITHM_NUMBERS = [f"{str(int(a))}" for a in ALGORITHMS]

def single_value(s):
    assert len(s) == 1
    return s[0]

def removesuffix(s, suf):
    if s[-len(suf):] == suf:
        return s[:-len(suf)]
    return s

by = ['resolver_group', 'resolver_name']  # resolver_addr
t = resolvers[resolvers['resolver_transport'] == 'UDP/TCP'].sort_values(by).groupby(by).agg({
    f'supports_{a}': [single_value]
    for a in ALGORITHMS
}).reset_index()
t.columns = ['Group', 'Resolver'] + ALGORITHM_NUMBERS

del t['Group']
formatters = {
    algorithm_name: lambda val: {True: r'\cmark', False: r'\xmark', None: '??'}[val]
    for algorithm_name in ALGORITHM_NUMBERS
}
formatters.update({
    'Group': lambda s: RESOLVER_GROUPS.get(s, s),
    'Resolver': lambda s: RESOLVER_NAMES.get(removesuffix(removesuffix(s, '-dot'), '-doh'), s),
})
print(t.to_latex(index=False, formatters=formatters, escape=False, column_format='lllcccc'))
# Out:
# \begin{tabular}{lllcccc}
# \toprule
#                 Resolver &      5 &      8 &     13 &     15 &     16 \\
# \midrule
#             Bind v9.11.3 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#      Knot Resolver 5.3.2 & \cmark & \cmark & \cmark & \xmark & \xmark \\
# Power DNS Recursor 4.6.0 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            Unbound 1.6.7 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#      Windows Server 2012 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#   Windows Server 2012 R2 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#      Windows Server 2016 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#      Windows Server 2019 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            101-255-64-66 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           101-78-140-254 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           101-98-202-208 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            102-222-12-30 & \cmark & \cmark & \cmark & \cmark &   None \\
#          102-222-146-254 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           102-223-143-16 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            102-33-43-157 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            103-103-43-25 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            103-106-2-218 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           103-112-237-58 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           103-135-135-99 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           103-14-229-117 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#          103-144-160-127 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#          103-145-165-107 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           103-153-190-43 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          103-154-157-202 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           103-156-66-243 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          103-163-162-132 & \cmark & \xmark & \xmark & \cmark & \xmark \\
#            103-164-39-67 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            103-168-90-97 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            103-19-10-244 &   None &   None &   None & \cmark &   None \\
#          103-214-187-142 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#          103-230-182-202 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          103-240-110-241 & \cmark &   None &   None &   None &   None \\
#            103-28-86-162 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           103-49-157-191 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           103-92-204-235 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            103-92-207-84 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           104-131-88-125 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            104-152-27-67 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#          105-247-123-164 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           106-38-118-232 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          109-176-189-178 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            109-201-64-91 & \cmark & \cmark & \cmark &   None &   None \\
#           110-170-61-216 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            111-204-95-30 & \cmark &   None &   None &   None & \xmark \\
#            111-98-83-172 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           115-42-228-247 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            115-62-236-36 & \xmark & \cmark & \cmark & \xmark & \xmark \\
#          116-206-215-129 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           116-241-18-173 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           118-140-245-90 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           119-110-209-82 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             119-42-74-74 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            12-161-77-225 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           12-172-249-110 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            12-227-80-228 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             12-246-9-138 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             12-25-249-55 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             12-88-120-50 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            12-94-144-154 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            120-89-47-225 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            121-100-49-93 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           122-17-202-129 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            130-61-248-92 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           131-108-185-10 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          131-161-252-126 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            134-119-3-209 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           138-122-53-166 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           138-255-23-113 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            139-28-255-28 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            14-116-160-88 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            14-136-95-122 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            14-224-148-39 & \cmark & \cmark & \cmark & \cmark &   None \\
#            144-217-35-47 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#          151-237-140-101 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#          151-237-206-172 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            153-33-121-79 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#              154-0-9-138 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          154-127-228-109 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            154-65-33-158 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          155-138-156-113 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           156-255-68-198 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           158-69-199-140 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          159-192-120-127 & \cmark & \cmark & \cmark & \cmark &   None \\
#           160-119-118-56 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           162-159-57-106 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           162-159-57-169 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           162-159-57-206 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          162-191-226-100 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            167-99-214-87 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            168-121-56-17 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           168-194-87-248 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            168-90-141-11 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           168-90-145-193 & \cmark & \cmark & \cmark & \cmark &   None \\
#           170-150-128-32 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           170-233-122-45 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           170-238-164-68 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           170-238-164-70 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          170-246-172-216 & \cmark & \cmark & \cmark & \cmark &   None \\
#          170-246-172-232 & \cmark & \cmark & \cmark & \cmark &   None \\
#            170-83-16-249 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            171-103-84-51 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          172-105-145-174 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            172-64-46-198 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            174-64-104-98 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            176-104-55-32 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            176-109-2-212 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           176-120-39-120 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           176-123-217-46 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           176-236-210-18 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           177-103-138-39 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            177-221-117-9 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#              177-36-20-9 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           177-53-154-209 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             177-54-228-1 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            177-73-151-96 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#             177-8-252-44 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          178-205-135-194 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            178-251-77-46 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           178-46-133-106 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            181-16-234-43 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          181-176-173-130 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          181-189-223-120 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           182-53-228-197 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             183-6-104-38 & \cmark & \xmark & \xmark & \xmark & \xmark \\
#             183-6-165-70 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           185-110-23-197 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            185-135-17-92 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#          185-161-199-103 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#             185-18-48-68 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          185-203-140-146 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           185-228-169-46 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            185-238-121-2 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            185-239-88-54 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           185-90-132-253 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#             186-74-23-36 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           186-96-116-228 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           187-120-33-183 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           188-129-133-35 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           188-207-40-246 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           188-241-34-228 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          190-131-224-140 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            190-214-52-14 & \cmark & \cmark & \cmark & \cmark &   None \\
#            190-83-60-254 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           190-85-139-166 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          192-153-186-177 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            192-232-14-91 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           193-192-117-89 & \cmark & \cmark & \cmark &   None &   None \\
#            193-93-219-90 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           194-233-64-192 & \xmark & \cmark & \cmark & \xmark & \xmark \\
#             194-244-9-38 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          195-136-206-212 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           195-14-169-182 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           195-190-142-61 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          195-191-187-130 &   None &   None & \cmark & \cmark & \xmark \\
#           195-206-60-116 & \cmark & \xmark & \xmark & \cmark & \xmark \\
#             195-53-46-78 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           195-95-147-244 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             196-61-22-70 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           198-58-122-198 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#             199-38-120-5 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           200-229-78-159 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            200-229-78-76 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             200-5-53-218 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           201-164-60-158 & \cmark & \cmark & \cmark & \cmark &   None \\
#          202-124-229-227 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#          202-131-243-126 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            202-21-113-42 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            202-70-65-153 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           203-101-178-77 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          203-150-167-126 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            203-23-238-41 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            203-81-100-26 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#              203-90-24-3 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            204-195-36-61 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           207-251-98-156 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           207-53-228-212 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           208-104-35-179 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           208-77-126-130 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#          212-113-200-106 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#          212-162-139-215 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#              212-3-217-9 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           212-46-195-106 & \cmark & \cmark & \cmark & \cmark &   None \\
#            213-14-142-14 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           213-168-38-154 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#          213-176-234-212 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            213-57-70-109 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           213-91-180-124 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           217-107-113-78 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           218-104-248-37 & \cmark &   None & \cmark &   None &   None \\
#           219-157-38-162 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           220-100-57-152 &   None &   None & \cmark &   None &   None \\
#          222-141-201-237 & \xmark & \cmark & \cmark & \xmark & \xmark \\
#          222-141-201-251 & \xmark & \xmark & \xmark & \xmark & \cmark \\
#          223-197-227-180 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            23-225-194-53 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            24-223-104-96 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             27-72-124-32 & \cmark & \cmark &   None & \cmark & \xmark \\
#             31-170-16-28 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            31-202-118-74 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#               31-30-0-58 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#              31-41-90-80 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           35-212-152-214 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#              37-143-24-6 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           38-126-107-177 & \cmark & \cmark & \cmark & \cmark &   None \\
#              38-146-85-2 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#              38-32-72-98 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            38-93-150-127 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             41-92-134-10 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            45-15-226-109 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           45-157-214-222 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           45-159-168-147 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            45-164-60-130 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#              45-174-8-50 & \cmark &   None &   None &   None &   None \\
#           45-184-219-240 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           45-184-219-242 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           45-185-253-143 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            45-187-95-195 & \cmark & \cmark & \cmark &   None & \xmark \\
#           45-191-106-146 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             45-232-87-18 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             45-234-80-75 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#             45-235-177-0 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           45-235-177-168 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#              45-235-2-81 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             45-4-144-137 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             45-64-104-51 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             45-79-149-36 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             45-90-28-114 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            46-101-237-69 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           46-140-206-246 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           46-146-204-241 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             46-21-184-45 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             46-226-44-60 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             49-248-82-98 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            5-178-233-235 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            5-181-248-209 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             5-185-80-154 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             5-196-95-139 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#              5-2-217-156 & \cmark & \cmark & \cmark & \cmark &   None \\
#              5-21-240-59 & \cmark & \xmark & \cmark & \xmark & \xmark \\
#            5-254-202-102 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#               5-58-1-171 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            50-231-92-154 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           50-235-115-198 & \cmark & \xmark & \xmark & \xmark & \xmark \\
#           51-178-122-252 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           51-210-154-120 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#              51-68-61-23 & \cmark & \cmark & \cmark & \cmark &   None \\
#               58-251-6-6 & \cmark & \cmark & \xmark & \cmark & \cmark \\
#             58-69-114-92 &   None & \cmark &   None & \cmark & \xmark \\
#             59-124-28-81 & \cmark & \xmark & \cmark & \xmark & \xmark \\
#            59-144-142-57 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             59-46-34-243 & \xmark & \xmark & \xmark & \cmark & \xmark \\
#             61-220-40-18 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#               61-5-200-2 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            65-120-119-55 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#              65-155-4-30 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            65-49-205-148 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#              65-70-23-41 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            66-128-246-23 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            66-128-246-49 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           66-128-249-120 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#             66-41-87-194 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            66-97-181-228 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           67-191-223-209 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             67-48-57-162 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            68-226-156-64 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           69-245-148-131 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#             69-70-38-250 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            70-171-47-183 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            70-171-48-249 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            70-171-50-185 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            71-14-240-217 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#              71-40-38-35 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#               73-50-42-9 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           74-205-204-230 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           75-118-137-246 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            75-78-236-206 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            75-78-238-160 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           77-137-105-251 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            77-137-108-64 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           77-137-109-246 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           77-137-110-171 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           77-137-110-176 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            78-133-244-62 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            78-158-19-196 & \cmark &   None &   None & \cmark & \xmark \\
#              8-20-247-72 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#              8-20-247-77 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#             80-249-46-23 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#              81-17-28-87 & \xmark & \cmark & \cmark & \xmark & \xmark \\
#            81-200-26-105 & \cmark & \cmark & \cmark & \cmark &   None \\
#           82-137-244-184 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           82-139-185-146 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           82-197-207-210 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            82-207-81-190 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#              83-1-108-26 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             83-14-242-46 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           83-149-173-166 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#             84-238-28-15 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#             85-114-21-84 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           85-163-105-249 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#             85-187-42-51 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             85-67-67-102 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            85-69-255-154 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             87-240-64-87 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             87-27-205-45 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#            87-98-175-234 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           88-146-216-236 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            88-157-99-123 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#              89-24-8-182 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#             89-255-53-81 & \cmark & \cmark & \cmark &   None &   None \\
#             89-40-98-223 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#              89-42-92-23 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             91-121-29-74 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           91-149-165-174 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           91-219-215-227 & \cmark & \cmark & \cmark & \cmark & \cmark \\
#           91-221-177-198 & \xmark & \xmark & \cmark & \cmark & \xmark \\
#           91-238-161-113 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            91-239-18-208 & \cmark & \cmark &   None & \xmark & \xmark \\
#             91-244-73-31 & \cmark & \cmark & \cmark & \xmark & \xmark \\
#            92-255-174-68 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             92-43-189-13 & \cmark & \cmark & \cmark &   None &   None \\
#            93-145-93-142 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           94-141-230-130 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             94-53-67-140 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            95-155-36-186 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            96-30-125-130 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#             98-215-200-7 & \cmark & \cmark & \cmark & \cmark & \xmark \\
#           Cisco Umbrella & \cmark & \cmark & \cmark & \cmark & \cmark \\
#      Cloudflare Resolver & \cmark & \cmark & \cmark & \cmark & \xmark \\
#        Comodo Secure DNS & \cmark & \cmark & \cmark & \cmark & \cmark \\
#               cznic ODVR & \cmark & \cmark & \cmark & \cmark & \xmark \\
#            Freenom World & \cmark & \cmark & \cmark & \xmark & \xmark \\
#        Google Public DNS & \cmark & \cmark & \cmark & \cmark & \xmark \\
#               Oracle Dyn & \cmark & \cmark & \cmark & \xmark & \xmark \\
#           Quad9 Resolver & \cmark & \cmark & \cmark & \cmark & \xmark \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Define Attack Strategies
#
# For each zone and each resolver, we run a number of different attack strategies. Which exactly is determined below.

# %%
attacks = [
    {'name': 'replace signature number with 253 (PRIVATEDNS) and fake content', 'instructions': ('rs17', 'at')},
    {'name': 'replace signature number with 17 (unassigned) and fake content', 'instructions': ('rs253', 'at')},
    {'name': 'replace signature number with ed448 and fake content', 'instructions': ('rs16', 'at')},
    {'name': 'replace signature number with ed25519 and fake content', 'instructions': ('rs15', 'at')},
    {'name': 'replace signature number with ecdsap256sha256 and fake content', 'instructions': ('rs13', 'at')},
    {'name': 'replace signature number with rsasha256 and fake content', 'instructions': ('rs8', 'at')},
    {'name': 'remove all signatures except ed448 and fake content', 'instructions': ('at',) + tuple(f'ds{a}' for a in ALGORITHMS if a < dns.dnssec.ED448)},
    {'name': 'remove all signatures except ed25519 and ed448 and fake content', 'instructions': ('at',) + tuple(f'ds{a}' for a in ALGORITHMS if a < dns.dnssec.ED25519)},
    {'name': 'strip all signatures and fake content', 'instructions': ('at',) + tuple(f'ds{a}' for a in ALGORITHMS)},
    {'name': 'invalidate signature', 'instructions': ('ms',),}
]
attacks = pd.DataFrame(attacks)
attacks['prefix'] = attacks.apply(lambda row: f"mitm-{'-'.join(row['instructions'])}", axis=1)
attacks = attacks.set_index('prefix')
attacks
# Out:
#                                                                              name  \
# prefix
# mitm-rs17-at                    replace signature number with 253 (PRIVATEDNS)...
# mitm-rs253-at                   replace signature number with 17 (unassigned) ...
# mitm-rs16-at                    replace signature number with ed448 and fake c...
# mitm-rs15-at                    replace signature number with ed25519 and fake...
# mitm-rs13-at                    replace signature number with ecdsap256sha256 ...
# mitm-rs8-at                     replace signature number with rsasha256 and fa...
# mitm-at-ds5-ds8-ds13-ds15       remove all signatures except ed448 and fake co...
# mitm-at-ds5-ds8-ds13            remove all signatures except ed25519 and ed448...
# mitm-at-ds5-ds8-ds13-ds15-ds16              strip all signatures and fake content
# mitm-ms                                                      invalidate signature
#
#                                                     instructions
# prefix
# mitm-rs17-at                                          (rs17, at)
# mitm-rs253-at                                        (rs253, at)
# mitm-rs16-at                                          (rs16, at)
# mitm-rs15-at                                          (rs15, at)
# mitm-rs13-at                                          (rs13, at)
# mitm-rs8-at                                            (rs8, at)
# mitm-at-ds5-ds8-ds13-ds15             (at, ds5, ds8, ds13, ds15)
# mitm-at-ds5-ds8-ds13                        (at, ds5, ds8, ds13)
# mitm-at-ds5-ds8-ds13-ds15-ds16  (at, ds5, ds8, ds13, ds15, ds16)
# mitm-ms                                                    (ms,)

# %% [markdown]
# ## Run Attack Evaluation
#
# Here, we define how to collect data for a given resolver, zone config, and attack; then we run the check for all combinations of resolvers, zones, and attacks.

# %%
def check_attack(addr, resolver, prefix, zone):
    try:
        # qname = dns.name.from_text(prefix, origin=zone)
        qname = dns.name.from_text(f"{prefix}-tok{resolver['token']}", origin=zone)
        r1 = query(qname, addr, cd=False, rdtype=TXT)
        logging.info(f'Response:\n{r1}')
        return {
            'resolver_addr': addr,
            'zone': zone,
            'attack': prefix,
            'status': 'ok',
            'rcode': r1.rcode(),
            'response': r1,
            'evil_content': 'evil' in str(r1) or 'ms-' in qname.to_text(),
        }
    except dns.exception.Timeout:
        return {
            'resolver_addr': addr,
            'zone': zone,
            'attack': prefix,
            'status': 'timeout',
        }
    except Exception as e:
        logging.warning(f"Exception: {type(e).__name__}: {e}")
        return {
            'resolver_addr': addr,
            'zone': zone,
            'attack': prefix,
            'status': e,
        }

# %% [markdown]
# The following cell runs the attack data collection for the product of `attacks`, `zones`, and `resolvers`. Depending on the size of these lists, and on the multi-threading configuration, this may take minutes to hours.

# %%
attack_results = run(check_attack, [(addr, resolver, prefix, zone) for prefix, _ in attacks.iterrows() for zone, _ in zones.iterrows() for addr, resolver in resolvers.iterrows()])
attack_results = pd.DataFrame(attack_results)
attack_results
# Out:
#   1%|▊                                                                                                                                                                 | 882/172500 [01:12<4:00:33, 11.89it/s]WARNING:root:Exception: UnexpectedSource: got a response from ('192.232.14.91', 53) instead of ('220.100.57.152', 53)
#   3%|████▉                                                                                                                                                            | 5337/172500 [07:57<2:53:07, 16.09it/s]

# %%
assert False  # nothing adapted over v2 below. Expect unintended behavior (e.g. due to token attribute in resolvers data frame).

# %%
# combine attack data with details on resolvers, zones, and attacks
results = attack_results.join(resolvers, on='resolver_addr').join(zones, on='zone').join(attacks, on='attack')
assert len(attack_results) == len(results), (len(attack_results), len(results)) # make sure this worked as expected

# %%
# save raw data
results.to_pickle(datetime.now().strftime("results-%Y-%m-%d--%H-%M-%S.pickle"))

# %%
# load data
#results = pd.read_pickle("results-2021-10-11--15-25-17.pickle")

# %%
# extract and enrich data
results['status_str'] = results.apply(lambda row: str(row['status']), axis=1)
results['supported_ds'] = results.apply(lambda row: tuple(set(row['ds']) & set(row['support'])), axis=1)
results['supported_dnskey'] = results.apply(lambda row: tuple(set(row['dnskey']) & set(row['support'])), axis=1)
results['validation_paths'] = results.apply(lambda row: tuple(set(row['dnskey']) & set(row['ds'])), axis=1)
results['qname'] = results.apply(lambda row: dns.name.from_text(row['attack'], origin=row['zone']), axis=1)
results['evil_content'] = results['qname'].apply(lambda x: '-ms' in x.to_text()) | results['evil_content']
results['zone_prefix'] = results.apply(lambda row: row['zone'][0].decode(), axis=1)
results['zone_config'] = results.apply(lambda row: f"DS: {','.join(str(int(e)) for e in row['ds'])} DNSKEY: {','.join(str(int(e)) for e in row['dnskey'])}", axis=1)
results['zone_name'] = results.apply(lambda row: row['zone'].to_text(), axis=1)

def rrsig(row):
    ALGORITHMS = range(255)
    if '-rs' in row['attack'] and '-ds' in row['attack']:
        raise NotImplemented
    if '-rs' in row['attack']:
        for a in reversed(ALGORITHMS):  # reverse to avoid matching rs1 instead of rs10
            if f'-rs{a}' in row['attack']:
                return tuple([a])
    if '-ds' in row['attack']:
        return tuple(set(row['ds']) - {a for a in ALGORITHMS if f'ds{a}' in row['attack']})
    return row['ds']

results['rrsig'] = results.apply(rrsig, axis=1)

results['num_ds'] = results.apply(lambda row: len(row['ds']), axis=1)
results['num_supported_ds'] = results.apply(lambda row: len(row['supported_ds']), axis=1)
results['num_unsupported_ds'] = results.apply(lambda row: row['num_ds'] - row['num_supported_ds'], axis=1)
results['num_dnskey'] = results.apply(lambda row: len(row['dnskey']), axis=1)
results['num_supported_dnskey'] = results.apply(lambda row: len(row['supported_dnskey']), axis=1)
results['num_unsupported_dnskey'] = results.apply(lambda row: row['num_dnskey'] - row['num_supported_dnskey'], axis=1)
results['supported_rrsig'] = results.apply(lambda row: tuple(set(row['rrsig']) & set(row['support'])), axis=1)
results['num_rrsig'] = results.apply(lambda row: len(row['rrsig']), axis=1)
results['num_supported_rrsig'] = results.apply(lambda row: len(row['supported_rrsig']), axis=1)
results['num_unsupported_rrsig'] = results.apply(lambda row: row['num_rrsig'] - row['num_supported_rrsig'], axis=1)
results['has_supported'] = results.apply(lambda row: row['num_rrsig'] - row['num_supported_rrsig'], axis=1)
results['has_supported_ds'] = results.apply(lambda row: bool(row['num_supported_ds']), axis=1)
results['has_unsupported_ds'] = results.apply(lambda row: bool(row['num_unsupported_ds']), axis=1)
results['has_supported_rrsig'] = results.apply(lambda row: bool(row['num_supported_rrsig']), axis=1)
results['has_unsupported_rrsig'] = results.apply(lambda row: bool(row['num_unsupported_rrsig']), axis=1)

def ds_support_status(row):
    if row['has_supported_ds'] and row['has_unsupported_ds']:
        return 'both'
    if row['has_supported_ds']:
        return 'supported'
    if row['has_unsupported_ds']:
        return 'unsupported'
    return 'none'
    
results['ds_support_status'] = results.apply(ds_support_status, axis=1)

def rrsig_support_status(row):
    if row['has_supported_rrsig'] and row['has_unsupported_rrsig']:
        return 'both'
    if row['has_supported_rrsig']:
        return 'supported'
    if row['has_unsupported_rrsig']:
        return 'unsupported'
    return 'none'
    
results['rrsig_support_status'] = results.apply(rrsig_support_status, axis=1)

def rrsig_dangling_status(row):
    if set(row['rrsig']).issubset(row['ds']):
        return 'no dangling'
    if set(row['ds']).issubset(row['rrsig']):
        return 'some sangling'
    return 'all dangling'
    
results['rrsig_dangling_status'] = results.apply(rrsig_dangling_status, axis=1)

def poc(row):
    if row['behavior_correct']:
        return None
    resolver_addr = row['resolver_addr']
    attack = row['attack']
    zone_prefix = row['zone_prefix']
    resolver_transport = row['resolver_transport']
    if resolver_transport == 'UDP/TCP':
        return f"dig @{resolver_addr} TXT +dnssec {attack}.{zone_prefix}.downgrade.dedyn.io"
    elif resolver_transport == 'DoH':
        resolver_addr = resolver_addr.split('//', 1)[1].split('/', 1)[0]
        return f"kdig @{resolver_addr} TXT +dnssec +https {attack}.{zone_prefix}.downgrade.dedyn.io"
    elif resolver_transport == 'DoT':
        return f"kdig TXT @{resolver_addr} +tls-ca +tls-host={resolver_addr} {attack}.{zone_prefix}.downgrade.dedyn.io"
    logging.warning(f'No POC for {resolver_transport=}')
    
results['poc'] = results.apply(poc, axis=1)

results['Resolver'] = results.apply(lambda row: f"{RESOLVER_NAMES.get(removesuffix(removesuffix(row['resolver_name'], '-dot'), '-doh'), row['resolver_name'])} ({row['resolver_transport']})", axis=1)

results['ds_numbers'] = results.apply(lambda row: tuple(sorted(int(a) for a in row['ds'])), axis=1)
results['dnskey_numbers'] = results.apply(lambda row: tuple(sorted(int(a) for a in row['dnskey'])), axis=1)

# %% [markdown]
# To determine if the resolver behaved correctly for any given query, we look at the response code and if there was evil content in the response:

# %%
def behavior_correct(row):
    if row['status'] != 'ok':
        return None
    
    if not row['supported_ds']:
        # resolvers will treat zone as insecure if there is no supported DS algorithm
        # we don't care if resolvers give SERVFAIL more often than appropriate
        return True
    
    if row['rcode'] == dns.rcode.Rcode.NOERROR and row['evil_content']:
        # evil content present, i.e. the signature invalid, but response wasn't SERVFAIL
        return False
    elif row['rcode'] == dns.rcode.Rcode.SERVFAIL: # we don't see the content so cannot check for evil content:
        # desired behavior for invalid signatures
        # we don't care if resolvers give SERVFAIL more often than appropriate
        return True
    
    # something else we didnt expect?
    logging.warning(f"Don't know if behavior is correct for rcode={row['rcode']} evil_content={row['evil_content']} "
                    f"ds={', '.join(str(int(a)) for a in row['ds'])} "
                    f"supported_ds={', '.join(str(int(a)) for a in row['supported_ds'])} qname={row['qname']}")
    logging.warning(row['response'])
    
    return None

results['behavior_correct'] = results.apply(behavior_correct, axis=1)

# %% [markdown]
# ## Successful Attacks

# %%
pd.options.display.max_rows = len(resolvers) * len(attacks)

def values(s):
    return '; '.join(s)

def zone_proportion(s):
    return len(s) / len(zones)

attack_success_rate = results.groupby(['attack', 'name', 'resolver_name', 'resolver_addr'], dropna=False).agg({
    'behavior_correct': [len, 'mean']
}).reset_index()
attack_success_rate[attack_success_rate[('behavior_correct', 'mean')] < 1].head(10)

# %% [markdown]
# ## Resolver Behavior Correctness (Over Attacks and Configurations)

# %%
pd.options.display.max_rows = len(resolvers) * len(attacks) * 2

def status_ok(s):
    return (s == 'ok').mean()

results.groupby(['resolver_group', 'resolver_name'], dropna=False).agg({
    'status': [status_ok],
    'behavior_correct': ['mean'],
})

# %% [markdown]
# ## Determine Conditions under which Resolvers are Vulnerable

# %%
def resolver_vuln(s):
    assert len(s) <= 1
    return bool(next(iter(s)))

vuln = 'resolver vulnerable under the following condition'
by = ['Resolver', 'ds_support_status', 'rrsig_dangling_status', 'rrsig_support_status']
affected_resolvers = results.sort_values(by[0]).groupby(by).agg({
    'behavior_correct': ['mean']
}).reset_index()
affected_resolvers.columns = affected_resolvers.columns.droplevel(1)
affected_resolvers = affected_resolvers.pivot(index=by[0], columns=by[1:], values=['behavior_correct'])
affected_resolvers.style.apply(lambda row: ['color: red' if v < 1 else 'color: grey' for v in row], axis=1)

# %%
def resolver_vuln(s):
    assert len(s) <= 1
    return bool(next(iter(s)))

vuln = 'resolver vulnerable under the following condition'
results['DS Alg. Supported'] = results['ds_support_status']
results['RRSIG Alg. Supported'] = results['rrsig_support_status']
by = ['Resolver', 'ds_support_status', 'rrsig_dangling_status', 'rrsig_support_status']
affected_resolvers = results[results['behavior_correct'] == False].sort_values(by[0]).groupby(by).agg({
    'behavior_correct': ['min']
}).reset_index()
affected_resolvers[vuln] = ~affected_resolvers[('behavior_correct', 'min')]
affected_resolvers.columns = affected_resolvers.columns.droplevel(1)
affected_resolvers = affected_resolvers.groupby(by).agg({
    vuln: [resolver_vuln]
}).reset_index()
affected_resolvers.columns = affected_resolvers.columns.droplevel(1)
affected_resolvers = affected_resolvers.pivot(index=by[0], columns=by[1:], values=[vuln])
affected_resolvers.style.apply(lambda row: [{True: 'color: red;', False: 'color: darkgreen;'}.get(v, 'color: grey;') for v in row], axis=1)

# %% [markdown]
# ### Behavior for Given Resolver with Respect to Attack and DS/DNSKEY Configuration

# %%
given_resolver = '8.8.8.8'

# %% [markdown]
# The following table shows on the y-axis the DS and DNSKEY configuration of a zone and the attack on the x-axis. It is colored by the behavioral correctness of the resolver.

# %%
results[results['resolver_addr'] == given_resolver].sort_values(['ds_numbers', 'dnskey_numbers', 'attack']).groupby(['ds_numbers', 'dnskey_numbers', 'attack']).agg({
    'behavior_correct': ['mean', len]
}).reset_index().pivot(columns=[('attack', '')], index=[('ds_numbers', ''), ('dnskey_numbers', '')], values=[('behavior_correct', 'mean')]).style.apply(lambda row: ['background-color: red;' if val < 1 else None for val in row], axis=1)

# %% [markdown]
# The following table shows on the y-axis the DS, RRSIG support status with respect to `given_resolver` (after attack) and the attack on the x-axis. It is colored by the behavioral correctness of the resolver. **It only shows configurations with DS algos == DNSKEY algos.**

# %%
results['has_covered_rrsig'] = results.apply(lambda row: bool(set(row['ds']) & set(row['dnskey']) & set(row['rrsig'])), axis=1)

results[(results['resolver_addr'] == given_resolver) & (results['ds'] == results['dnskey'])].sort_values(
    ['num_supported_ds', 'num_unsupported_ds', 'num_supported_rrsig', 'num_unsupported_rrsig', 'has_covered_rrsig', 'attack']).groupby(
    ['has_supported_ds', 'has_unsupported_rrsig', 'has_covered_rrsig', 'has_supported_rrsig', 'attack']).agg({
    'behavior_correct': ['mean', len],
    'zone_config': [values],
}).reset_index().pivot(columns=[('attack', '')], index=[
    ('has_supported_ds', ''), ('has_unsupported_rrsig', ''), ('has_covered_rrsig', ''), ('has_supported_rrsig', '')], 
                       values=[('behavior_correct', 'mean')]).style.apply(lambda row: ['background-color: red;' if val < 1 else None for val in row], axis=1)

# %% [markdown]
# The following table shows on the y-axis the DS, RRSIG support status with respect to `given_resolver` (after attack) and the attack on the x-axis. It is colored by the behavioral correctness of the resolver. **It only shows configurations with DS algos != DNSKEY algos.**

# %%
results['has_covered_rrsig'] = results.apply(lambda row: bool(set(row['ds']) & set(row['dnskey']) & set(row['rrsig'])), axis=1)

results[(results['resolver_addr'] == given_resolver) & (results['ds'] != results['dnskey'])].sort_values(
    ['num_supported_ds', 'num_unsupported_ds', 'num_supported_rrsig', 'num_unsupported_rrsig', 'has_covered_rrsig', 'attack']).groupby(
    ['has_supported_ds', 'has_unsupported_rrsig', 'has_covered_rrsig', 'has_supported_rrsig', 'attack']).agg({
    'behavior_correct': ['mean', len],
    'zone_config': [values],
}).reset_index().pivot(columns=[('attack', '')], index=[
    ('has_supported_ds', ''), ('has_unsupported_rrsig', ''), ('has_covered_rrsig', ''), ('has_supported_rrsig', '')], 
                       values=[('behavior_correct', 'mean')]).style.apply(lambda row: ['background-color: red;' if val < 1 else None for val in row], axis=1)

# %% [markdown]
# ## Vulnerable DS Configurations per Resolver

# %% [markdown]
# The following analysis shows the vulnerability of the resolvers with respect to any attack, conditioned on the DS configuration of the zone. It includes data of the prevalence of the DS configurations in the wild.

# %%
# TODO replace with Elias' data
# values taken from Crawler Tranco
tranco_ds_distribution = {(1,): 4,
 (3,): 1,
 (5,): 882,
 (5, 7): 2,
 (5, 7, 8): 1,
 (5, 8): 20,
 (5, 10): 2,
 (5, 12): 1,
 (5, 13): 7,
 (7,): 1472,
 (7, 8): 8,
 (7, 8, 13, 14): 1,
 (7, 10): 1,
 (7, 13): 9,
 (8,): 21963,
 (8, 10): 5,
 (8, 13): 23,
 (8, 14): 1,
 (10,): 710,
 (10, 13): 2,
 (10, 14): 1,
 (12,): 2,
 (13,): 17862,
 (13, 15): 1,
 (14,): 267,
 (15,): 2}
tranco_ds_total = sum(c for c in tranco_ds_distribution.values())

# values taken from Crawler TLD
tld_ds_distribution = {(5,): 29, (7,): 34, (7, 8): 4, (8,): 1225, (10,): 33, (13,): 45}
tld_ds_total = sum(c for c in tld_ds_distribution.values())

# %%
def row_style(row):
    return ['color: red;' if behavior_correct is True else 'color: grey;' for behavior_correct in row]

def vulnerable(row):
    return {
        True: False,
        False: True,
    }.get(row['behavior_correct'], None)

results['Group'] = results.apply(lambda row: RESOLVER_GROUPS.get(row['resolver_group'], row['resolver_group']), axis=1)
#results['Group'] = results['resolver_group']
results['Resolver'] = results.apply(lambda row: RESOLVER_NAMES.get(removesuffix(removesuffix(row['resolver_name'], '-dot'), '-doh'), row['resolver_name']), axis=1)
results['Transport'] = results['resolver_transport']
results['DS Algorithms'] = results['ds_numbers']
results['Vulnerable'] = results.apply(vulnerable, axis=1)

vulnerable = results[~results['Vulnerable'].isna()].groupby(['Group', 'Resolver', 'Transport', 'DS Algorithms']).agg({
    'Vulnerable': [any]
}).reset_index()
vulnerable.columns = vulnerable.columns.droplevel(1)
vulnerable = vulnerable.pivot(columns=['DS Algorithms'], index=['Group', 'Resolver', 'Transport'], values=['Vulnerable'])
#vulnerable.columns = [('',) + x if not isinstance(x[1], tuple) else x + ('',) for x in vulnerable.columns]
vulnerable.columns = pd.MultiIndex.from_tuples(
    [(x[0], ', '.join(str(a) for a in x[1])) + (f"{tranco_ds_distribution.get(x[1], 0)/tranco_ds_total*100:.0f}\%", f"{tld_ds_distribution.get(x[1], 0)/tld_ds_total*100:.0f}\%") for x in vulnerable.columns],
    names=vulnerable.columns.names + ['Prevalence in Tranco 1M', 'Prevalence in TLDs']
)
vulnerable = vulnerable.reset_index(['Group'])
del vulnerable['Group']
vulnerable.style.apply(row_style, axis=1)

# %% [markdown]
# Visual inspection of above table shows that the vulnerabilities do not depend on the transport, hence it is removed below.

# %%
vulnerable = results[results['Vulnerable'] == True].groupby(['Group', 'Resolver', 'DS Algorithms']).agg({
    'Vulnerable': [any]
}).reset_index()
vulnerable.columns = vulnerable.columns.droplevel(1)
vulnerable = vulnerable.pivot(columns=['DS Algorithms'], index=['Group', 'Resolver'], values=['Vulnerable'])
#vulnerable.columns = [('',) + x if not isinstance(x[1], tuple) else x + ('',) for x in vulnerable.columns]
vulnerable.columns = pd.MultiIndex.from_tuples(
    [(x[0], ', '.join(str(a) for a in x[1])) + (f"{tranco_ds_distribution.get(x[1], 0)/tranco_ds_total*100:.0f}\%", f"{tld_ds_distribution.get(x[1], 0)/tld_ds_total*100:.0f}\%") for x in vulnerable.columns],
    names=vulnerable.columns.names + ['Prevalence in Tranco 1M', 'Prevalence in TLDs']
)
vulnerable = vulnerable.reset_index(['Group'])
del vulnerable['Group']
vulnerable.style.apply(row_style, axis=1)

# %%
# print for paper
formatters = {
    k: lambda val: {True: r'\cmark', False: r'', None: '??'}[val]
    for k in vulnerable.keys()
}
print(vulnerable.to_latex(index=True, formatters=formatters, escape=False, na_rep=''))

# RESOLVER DOWNGRADE VULNERABILITIES TABLE 3

# %% [markdown]
# ## Proof of Concepts for Vulnerabilities shown Above

# %%
def first_value(s):
    return next(iter(s))

results['ds_dnskey_match'] = results['ds'] == results['dnskey']
vulnerable = results[results['behavior_correct'] == False].sort_values(['ds_dnskey_match']).groupby(['resolver_group', 'resolver_name', 'ds_numbers']).agg({
    'poc': [first_value],
    'response': [first_value],
}).reset_index()
vulnerable.columns = vulnerable.columns.droplevel(1)
vulnerable = vulnerable.pivot(columns=['ds_numbers'], index=['resolver_group', 'resolver_name'], values=['poc', 'response'])
vulnerable
